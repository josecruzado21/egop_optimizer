# %%
import pandas as pd
import numpy as np
import sys
import os
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.stats import sem
import matplotlib as mpl

mpl.rcParams["axes.unicode_minus"] = False

# plot_paper.py lives in results/utils/ — add that to sys.path so we can import it.
# Kept as alias `plot` so existing plot.X() calls in this notebook still work.
sys.path.insert(0, str(Path.cwd() / 'utils'))
import plot_paper as plot

# %load_ext autoreload
# %autoreload 2
# Out:
# Using CMU Serif font at: C:\Users\hp\AppData\Local\Microsoft\Windows\Fonts\cmunrm.ttf

# %%
rsvd_components = [50, 100, 1000]

# %% [markdown]
# ## All the experiments with egop 0.01

# %% [markdown]
# ## Sequence

# %%
se_egop_1 = "csv/paper_results_data/20251215/sequence"

# %%
se_v_time_egop_1 = (
    "csv/paper_results_data/20251215/sequence/sequence_egop0.01_50trials.csv"
)

# %%
grouped_file_se_egop_1 = plot.get_group(se_egop_1)

# %% [markdown]
# ### Epoch plots

# %% [markdown]
# ### Sequence Time plot

# %% [markdown]
# #### With Sampling Time

# %%
plot.epoch_accuracy_analysis_time(
    se_egop_1, grouped_file_se_egop_1, rsvd_components, se_v_time_egop_1
)
# Out:
# Summary: Cumulative time to reach 99.5% of maximum accuracy
# ...
# Model      Mean         Median       Std          Min          Max
# ------------------------------------------------------------------------------------------
# $r=$50     60.08        57.09        16.19        32.75        92.49
# $r=$100    55.52        52.93        14.99        33.25        102.06
# $r=$1000   40.18        37.83        10.36        27.52        81.33
# Orig. Coors. 43.86        42.58        11.86        23.24        71.80
# ...

# %%
plot.epoch_accuracy_analysis_time(
    se_egop_1, grouped_file_se_egop_1, rsvd_components, se_v_time_egop_1
)
# Out:
# Summary: Cumulative time to reach 99.5% of maximum accuracy
# ...
# Model      Mean         Median       Std          Min          Max
# ------------------------------------------------------------------------------------------
# $r=$50     60.08        57.09        16.19        32.75        92.49
# $r=$100    55.52        52.93        14.99        33.25        102.06
# $r=$1000   40.18        37.83        10.36        27.52        81.33
# Orig. Coors. 43.86        42.58        11.86        23.24        71.80
# ...

# %%
plot.loss_plot(se_egop_1, grouped_file_se_egop_1, rsvd_components, "train_loss")
# Out:
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.

# %% [markdown]
# ## Vectorize

# %%
vc_egop_1 = "csv/paper_results_data/20251215/vectorize"
vc_v_time_egop_1 = (
    "csv/paper_results_data/20251215/vectorize/vector_egop0.01_50trials.csv"
)
grouped_file_vc_egop_1 = plot.get_group(vc_egop_1)

# %% [markdown]
# ### Epoch Plots

# %% [markdown]
# ### Time Plots

# %% [markdown]
# #### With Sampling Time

# %%
plot.epoch_accuracy_analysis_time(
    vc_egop_1,
    grouped_file_vc_egop_1,
    rsvd_components,
    vc_v_time_egop_1,
    save_path="figures/aux_sub_fig_timing_valacc.pdf",
)
# Out:
# Summary: Cumulative time to reach 99.5% of maximum accuracy
# ...
# Model      Mean         Median       Std          Min          Max
# ------------------------------------------------------------------------------------------
# $r=$50     61.31        58.25        21.00        28.26        117.13
# $r=$100    54.67        51.94        14.75        28.91        98.13
# $r=$1000   36.64        32.31        11.14        25.51        79.02
# Orig. Coors. 44.85        43.33        11.99        23.02        74.39
# ...

# %%
plot.loss_plot(
    vc_egop_1,
    grouped_file_vc_egop_1,
    rsvd_components,
    "train_loss",
    save_path="figures/aux_main_fig_plots.pdf",
)
# Out:
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.

# %%
plot.loss_plot(
    vc_egop_1,
    grouped_file_vc_egop_1,
    rsvd_components,
    "val_loss",
    save_path="figures/aux_main_fig_plots_val_loss.pdf",
)

# %% [markdown]
# # Visualizing results from 12/13 (including other rsvd values)

# %%
vc_egop_all = "csv/paper_results_data/20251213/vectorize"
vc_v_time_egop_all = (
    "csv/paper_results_data/20251213/vectorize/vector_egop0.01_50trials.csv"
)
grouped_file_vc_egop_all = plot.get_group(vc_egop_all)

# %%
rsvd_components = [50, 100, 1000]

plot.epoch_accuracy_analysis_time(
    vc_egop_all,
    grouped_file_vc_egop_all,
    rsvd_components,
    vc_v_time_egop_all,
    save_path="figures/aux_sub_fig_timing_valacc.pdf",
)
# Out:
# Summary: Cumulative time to reach 99.5% of maximum accuracy
# ...
# Model      Mean         Median       Std          Min          Max
# ------------------------------------------------------------------------------------------
# $r=$50     61.31        58.25        21.00        28.26        117.13
# $r=$100    54.67        51.94        14.75        28.91        98.13
# $r=$1000   36.64        32.31        11.14        25.51        79.02
# Orig. Coors. 44.85        43.33        11.99        23.02        74.39
# ...

# %%
plot.loss_plot(
    vc_egop_all,
    grouped_file_vc_egop_all,
    rsvd_components,
    "train_loss",
    # save_path="figures/aux_main_fig_plots_val_loss.pdf",
)
# Out:
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.

# %%
plot.epoch_accuracy_analysis_time(
    vc_egop_all,
    grouped_file_vc_egop_all,
    rsvd_components,
    vc_v_time_egop_all,
    save_path="figures/aux_sub_fig_timing_valacc.pdf",
)
# Out:
# Summary: Cumulative time to reach 99.5% of maximum accuracy
# ...
# Model      Mean         Median       Std          Min          Max
# ------------------------------------------------------------------------------------------
# $r=$50     61.31        58.25        21.00        28.26        117.13
# $r=$100    54.67        51.94        14.75        28.91        98.13
# $r=$1000   36.64        32.31        11.14        25.51        79.02
# Orig. Coors. 44.85        43.33        11.99        23.02        74.39
# ...

# %%
rsvd_components = [50, 100, 200, 400, 800, 1000, 2000]
plot.timing_plot_only(
    vc_egop_all,
    grouped_file_vc_egop_all,
    rsvd_components,
    vc_v_time_egop_all,
    save_path="figures/aux_timing.pdf",
)
# Out:
# Summary: Cumulative time to reach 99.5% of maximum accuracy
# ...
# Model      Mean         Median       Std          Min          Max
# ------------------------------------------------------------------------------------------
# $r=$50     61.31        58.25        21.00        28.26        117.13
# $r=$100    54.67        51.94        14.75        28.91        98.13
# $r=$200    48.50        46.27        13.98        26.35        99.48
# $r=$400    41.45        36.32        15.58        25.93        113.28
# $r=$800    41.91        34.81        17.67        22.87        103.19
# $r=$1000   36.64        32.31        11.14        25.51        79.02
# $r=$2000   38.14        33.68        11.52        26.01        81.14
# Orig. Coors. 45.30        43.48        12.15        23.02        74.92
# ...

# %%
plot.loss_plot(
    vc_egop_all,
    grouped_file_vc_egop_all,
    rsvd_components,
    "train_loss",
    save_path="figures/aux_main_fig_plots_train_loss.pdf",
)
# Out:
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.

# %%
plot.epoch_accuracy_analysis_time(
    vc_egop_all,
    grouped_file_vc_egop_all,
    rsvd_components,
    vc_v_time_egop_all,
    save_path="figures/aux_sub_fig_timing_valacc.pdf",
)
# Out:
# Summary: Cumulative time to reach 99.5% of maximum accuracy
# ...
# Model      Mean         Median       Std          Min          Max
# ------------------------------------------------------------------------------------------
# $r=$50     61.31        58.25        21.00        28.26        117.13
# $r=$100    54.67        51.94        14.75        28.91        98.13
# $r=$200    48.50        46.27        13.98        26.35        99.48
# $r=$400    41.45        36.32        15.58        25.93        113.28
# $r=$800    41.91        34.81        17.67        22.87        103.19
# $r=$1000   36.64        32.31        11.14        25.51        79.02
# $r=$2000   38.14        33.68        11.52        26.01        81.14
# Orig. Coors. 45.30        43.48        12.15        23.02        74.92
# ...
